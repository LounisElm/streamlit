# %%
# Imports nécessaires
import os
import time
import pandas as pd
from models import save_features_to_csv
import seaborn as sns
import matplotlib.pyplot as plt

# Sauvegarder les features
features_df = save_features_to_csv(
    features_method="all_features_with_genome",
    output_path="data/features"
)

print("\nAnalyse des valeurs manquantes :")
print(features_df.isnull().sum())

print("\nStatistiques descriptives :")
print(features_df.describe())

plt.figure(figsize=(12, 8))
sns.heatmap(features_df.corr(), cmap='coolwarm', center=0)
plt.title('Matrice de corrélation des features')
plt.tight_layout()
plt.show()
# Out:
# c:\Users\nicol\env_py312\Lib\site-packages\sklearn\feature_extraction\text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(
# c:\Users\nicol\env_py312\Lib\site-packages\sklearn\feature_extraction\text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(
# Features sauvegardées dans : data/features\features_all_features_with_genome_20250516_105557.csv
#
# Statistiques sur les features :
# Nombre de features : 100
# Nombre de films : 9702
#
# Aperçu des features :
#    n_character_title  title_year  movie_age decade_1900.0 decade_1910.0  \
# 1               16.0      1995.0       30.0         False         False
# 2               14.0      1995.0       30.0         False         False
# 3               23.0      1995.0       30.0         False         False
# 4               24.0      1995.0       30.0         False         False
# 5               34.0      1995.0       30.0         False         False
#
#   decade_1920.0 decade_1930.0 decade_1940.0 decade_1950.0 decade_1960.0  ...  \
# 1         False         False         False         False         False  ...
# 2         False         False         False         False         False  ...
# 3         False         False         False         False         False  ...
# 4         False         False         False         False         False  ...
# 5         False         False         False         False         False  ...
#
#   user_tag_pca_11 user_tag_pca_12 user_tag_pca_13 user_tag_pca_14  \
# 1             NaN             NaN             NaN             NaN
# 2             NaN             NaN             NaN             NaN
# 3             NaN             NaN             NaN             NaN
# 4             NaN             NaN             NaN             NaN
# 5             NaN             NaN             NaN             NaN
#
#   user_tag_pca_15  user_tag_pca_16  user_tag_pca_17  user_tag_pca_18  \
# 1             NaN              NaN              NaN              NaN
# 2             NaN              NaN              NaN              NaN
# 3             NaN              NaN              NaN              NaN
# 4             NaN              NaN              NaN              NaN
# 5             NaN              NaN              NaN              NaN
#
#    user_tag_pca_19  user_tag_cluster
# 1              NaN               NaN
# 2              NaN               NaN
# 3              NaN               NaN
# 4              NaN               NaN
# 5              NaN               NaN
#
# [5 rows x 100 columns]
#
# Analyse des valeurs manquantes :
# n_character_title     965
# title_year            967
# movie_age             967
# decade_1900.0         965
# decade_1910.0         965
#                      ...
# user_tag_pca_16      8702
# user_tag_pca_17      8702
# user_tag_pca_18      8702
# user_tag_pca_19      8702
# user_tag_cluster     8702
# Length: 100, dtype: int64
#
# Statistiques descriptives :
#        n_character_title   title_year    movie_age  genre_Action_popularity  \
# count        8737.000000  8735.000000  8735.000000              8737.000000
# mean           25.723360  1991.680481    33.319519                 0.538531
# std            12.783123    19.297869    19.297869                 1.182957
# min             8.000000  1902.000000     9.000000                 0.000000
# 25%            17.000000  1984.000000    19.000000                 0.000000
# 50%            22.000000  1997.000000    28.000000                 0.000000
# 75%            30.000000  2006.000000    41.000000                 0.000000
# max           158.000000  2016.000000   123.000000                 3.136763
#
#        genre_Adventure_popularity  genre_Animation_popularity  \
# count                 8737.000000                 8737.000000
# mean                     0.398938                    0.168039
# std                      1.056172                    0.735926
# min                      0.000000                    0.000000
# 25%                      0.000000                    0.000000
# 50%                      0.000000                    0.000000
# 75%                      0.000000                    0.000000
# max                      3.194792                    3.390660
#
#        genre_Children_popularity  genre_Comedy_popularity  \
# count                8737.000000              8737.000000
# mean                    0.199003                 1.146535
# std                     0.750504                 1.513474
# min                     0.000000                 0.000000
# 25%                     0.000000                 0.000000
# 50%                     0.000000                 0.000000
# 75%                     0.000000                 3.144154
# max                     3.029073                 3.144154
#
#        genre_Crime_popularity  genre_Documentary_popularity  ...  \
# count             8737.000000                   8737.000000  ...
# mean                 0.408224                      0.182923  ...
# std                  1.091648                      0.795332  ...
# min                  0.000000                      0.000000  ...
# 25%                  0.000000                      0.000000  ...
# 50%                  0.000000                      0.000000  ...
# 75%                  0.000000                      0.000000  ...
# max                  3.327105                      3.640549  ...
#
#        user_tag_pca_11  user_tag_pca_12  user_tag_pca_13  user_tag_pca_14  \
# count     1.000000e+03     1.000000e+03     1.000000e+03     1.000000e+03
# mean      1.643130e-17    -1.187939e-17    -4.551914e-18     1.132427e-17
# std       8.632754e-02     7.181520e-02     6.585571e-02     6.488727e-02
# min      -2.475087e-01    -3.175946e-01    -2.137966e-01    -1.755286e-01
# 25%      -5.615855e-02    -4.252683e-02    -4.087530e-02    -4.053642e-02
# 50%      -4.153744e-03     2.010581e-03    -2.330928e-03    -2.452645e-03
# 75%       5.478381e-02     4.130375e-02     4.130130e-02     3.543034e-02
# max       4.429283e-01     3.154076e-01     2.885214e-01     2.937847e-01
#
#        user_tag_pca_15  user_tag_pca_16  user_tag_pca_17  user_tag_pca_18  \
# count     1.000000e+03     1.000000e+03     1.000000e+03     1.000000e+03
# mean      8.951173e-18    -1.082467e-18     9.270362e-18     1.632028e-17
# std       5.818507e-02     5.544515e-02     4.913714e-02     4.640100e-02
# min      -2.009362e-01    -2.081147e-01    -2.538750e-01    -1.450054e-01
# 25%      -3.853786e-02    -3.588443e-02    -3.136574e-02    -2.946671e-02
# 50%       6.333941e-04    -3.275128e-04    -1.317670e-03     1.732707e-03
# 75%       3.588323e-02     3.440916e-02     3.299963e-02     3.131052e-02
# max       2.208708e-01     2.375558e-01     1.610431e-01     2.061155e-01
#
#        user_tag_pca_19  user_tag_cluster
# count     1.000000e+03       1000.000000
# mean      1.978973e-17          4.456000
# std       4.387239e-02          3.076285
# min      -1.963311e-01          0.000000
# 25%      -2.801777e-02          2.000000
# 50%       1.054399e-03          5.000000
# 75%       2.697224e-02          7.000000
# max       1.582897e-01          9.000000
#
# [8 rows x 88 columns]
